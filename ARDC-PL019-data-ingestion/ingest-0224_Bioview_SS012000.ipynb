# %%
import boto3
import io
import urllib
import s3fs
import json
from pathlib import Path
import attr
import numpy
import tiledb
import tiledb.cloud
from tiledb.cloud.compute import DelayedArrayUDF, Delayed
import pandas
import geopandas
import fiona
from fiona.session import AWSSession
import pystac
from scipy.stats import skew, kurtosis
import uuid

# %%
import pystac
from pystac.extensions.projection import ProjectionExtension
from pystac.extensions.pointcloud import (
    PointcloudExtension,
    SchemaType,
    PhenomenologyType,
    Schema,
    Statistic,
)

# %%
from reap_gsf import reap, data_model
from bathy_datasets import rhealpix, storage, geometry, asb_spreadsheet, stac_metadata

# %%
session = boto3.Session()
creds = session.get_credentials()

# %%
fs = s3fs.S3FileSystem(key=creds.access_key, secret=creds.secret_key, use_listings_cache=False)

# %%
uid = uuid.uuid4()

# %%
survey_uri = "s3://ausseabed-pl019-provided-data/JamesCookUniversity/0224_Bioview_SS012000/"
outdir_uri = "s3://ausseabed-pl019-ingested-data/L2/0224_Bioview_SS012000/"
asb_metadata_uri = "s3://ausseabed-pl019-provided-data/JamesCookUniversity/0224_Bioview_SS012000/spreadsheet-metadata.json"
survey_info_uri = "s3://ausseabed-pl019-provided-data/JamesCookUniversity/0224_Bioview_SS012000/schema-info.json"

# %%
base_prefix = "ga_ausseabed"
array_name = f"{base_prefix}_{uid}_bathymetry"
array_uri = f"{outdir_uri}{array_name}.tiledb"
tiledb_array_uri = f"tiledb://sixy6e/{array_name}"
soundings_cell_density_uri = f"{outdir_uri}{base_prefix}_{uid}_soundings-cell-density-resolution-12.geojson"
coverage_uri = f"{outdir_uri}{base_prefix}_{uid}_coverage.geojson"
stac_md_uri = f"{outdir_uri}{base_prefix}_{uid}_stac-metadata.geojson"

# %%
soundings_cell_density_uri_15 = f"{outdir_uri}{base_prefix}_{uid}_soundings-cell-density-resolution-15.geojson"

# %%
files = fs.glob(survey_uri + "**.gsf")
len(files)
# Out:
# 491

# %%
def get_sonar_metadata(json_uri):
    """
    Temporary func for pulling metadata from a sample GSF file.
    """
    with fs.open(json_uri) as src:
        md = json.loads(src.read())
    stream_task = Delayed("sixy6e/retrieve_stream", name="retrieve")(md["gsf_uri"], creds.access_key, creds.secret_key)
    dataframe_task = Delayed("sixy6e/decode_gsf", name="decode", image_name="3.7-geo")(stream_task, slice(10))
    df, finfo = dataframe_task.compute()
    sonar_metadata = finfo[3].record(0).read(stream_task.result()[0])
    history = attr.asdict(finfo[6].record(0).read(stream_task.result()[0]))
    for key, value in history.items():
        sonar_metadata[key] = value
    return sonar_metadata


def reduce_region_codes(results):
    """
    The reduce part of the map-reduce construct for handling the region_code counts.
    Combine all the region_code counts then summarise the results.
    """
    region_codes = [i[0] for i in results]
    timestamps = [i[1] for i in results]
    df = pandas.concat(region_codes)
    cell_count = df.groupby(["region_code"])["count"].agg("sum").to_frame("count").reset_index()
    
    timestamps_df = pandas.DataFrame(
        {
            "start_datetime": [i[0] for i in timestamps],
            "end_datetime": [i[1] for i in timestamps],
        }
    )

    start_end_timestamp = [
        timestamps_df.start_datetime.min().to_pydatetime(),
        timestamps_df.end_datetime.max().to_pydatetime(),
    ]

    return cell_count, start_end_timestamp


def gather_stats(results):
    """
    Gather the results from all the stats tasks and
    combine into a single dict.
    """
    data = {}
    for item in results:
        for key in item:
            data[key] = item[key]
    return data

# %%
def retrieve_stream(uri, access_key, skey):
    """
    Not testing the creation of the stream object at this point.
    But for testing, we also need to keep the download to occur only
    once.
    """
    session = boto3.Session(aws_access_key_id=access_key, aws_secret_access_key=skey)
    dev_resource = session.resource("s3")
    uri = urllib.parse.urlparse(uri)
    obj = dev_resource.Object(bucket_name=uri.netloc, key=uri.path[1:])
    stream = io.BytesIO(obj.get()["Body"].read())
    return stream, obj.content_length


def append_ping_dataframe(dataframe, array_uri, access_key, skey):
    """Append the ping dataframe read from a GSF file."""
    config = tiledb.Config(
        {"vfs.s3.aws_access_key_id": access_key, "vfs.s3.aws_secret_access_key": skey}
    )
    ctx = tiledb.Ctx(config=config)
    kwargs = {
        "mode": "append",
        "sparse": True,
        "ctx": ctx,
    }

    tiledb.dataframe_.from_pandas(array_uri, dataframe, **kwargs)


def ingest_gsf_slice(
    file_record, stream, access_key, skey, array_uri, idx=slice(None)
):
    """
    General steps:
    Extract the ping data.
    Calculate the rHEALPIX code.
    Summarise the rHEALPIX codes (frequency count).
    Get timestamps of first and last pings.
    Write the ping data to a TileDB array.
    res = [df.groupby(["key"])["key"].agg("count").to_frame("count").reset_index() for i in range(3)]
    df2 = pandas.concat(res)
    df2.groupby(["key"])["count"].agg("sum")
    """
    swath_pings = data_model.SwathBathymetryPing.from_records(file_record, stream, idx)
    swath_pings.ping_dataframe["region_code"] = rhealpix.rhealpix_code(
        swath_pings.ping_dataframe.X, swath_pings.ping_dataframe.Y, 15
    )

    # frequency of dggs cells
    cell_count = (
        swath_pings.ping_dataframe.groupby(["region_code"])["region_code"]
        .agg("count")
        .to_frame("count")
        .reset_index()
    )

    start_end_time = [
        swath_pings.ping_dataframe.timestamp.min().to_pydatetime(),
        swath_pings.ping_dataframe.timestamp.max().to_pydatetime(),
    ]

    # write to tiledb array
    append_ping_dataframe(swath_pings.ping_dataframe, array_uri, access_key, skey)

    return cell_count, start_end_time


def ingest_gsf_slices(gsf_uri, access_key, skey, array_uri, slices):
    """
    Ingest a list of ping slices from a given GSF file.
    """
    stream, stream_length = retrieve_stream(gsf_uri, access_key, skey)
    finfo = reap.file_info(stream, stream_length)
    ping_file_record = finfo[1]

    cell_counts = []
    start_end_timestamps = []

    for idx in slices:
        count, start_end_time = ingest_gsf_slice(
            ping_file_record, stream, access_key, skey, array_uri, idx
        )
        cell_counts.append(count)
        start_end_timestamps.append(start_end_time)

    # aggreate the ping slices and calculate the cell counts
    concatenated = pandas.concat(cell_counts)
    cell_count = (
        concatenated.groupby(["region_code"])["count"]
        .agg("sum")
        .to_frame("count")
        .reset_index()
    )

    # aggregate the min and max timestamps, then find the min max timestamps
    timestamps_df = pandas.DataFrame(
        {
            "start_datetime": [i[0] for i in start_end_timestamps],
            "end_datetime": [i[1] for i in start_end_timestamps],
        }
    )

    start_end_timestamp = [
        timestamps_df.start_datetime.min().to_pydatetime(),
        timestamps_df.end_datetime.max().to_pydatetime(),
    ]

    return cell_count, start_end_timestamp

# %%
def scatter(iterable, n):
    """
    Evenly scatters an interable by `n` blocks.
    Sourced from:
    http://stackoverflow.com/questions/2130016/splitting-a-list-of-arbitrary-size-into-only-roughly-n-equal-parts

    :param iterable:
        An iterable or preferably a 1D list or array.

    :param n:
        An integer indicating how many blocks to create.

    :return:
        A `list` consisting of `n` blocks of roughly equal size, each
        containing elements from `iterable`.
    """

    q, r = len(iterable) // n, len(iterable) % n
    res = (iterable[i * q + min(i, r) : (i + 1) * q + min(i + 1, r)] for i in range(n))
    return list(res)

# %%
with fs.open(survey_info_uri) as src:
    survey_info = json.loads(src.read())

# %%
#required_attributes = survey_info["schemas"][0]
# this is temporary. better to have it defined internally. or programmatically derived as a union of all schemas from all pings
required_attributes = [
    "Z",
    "across_track",
    "along_track",
    "beam_angle",
    "beam_angle_forward",
    "beam_flags",
    "beam_number",
    "centre_beam",
    "course",
    "depth_corrector",
    "gps_tide_corrector",
    "heading",
    "heave",
    "height",
    "horizontal_error",
    "ping_flags",
    "pitch",
    "roll",
    "sector_number",
    "separation",
    "speed",
    "tide_corrector",
    "timestamp",
    "travel_time",
    "vertical_error",
    "region_code",
]

# %%
sonar_metadata = get_sonar_metadata(files[0].replace(".gsf", ".json"))

# %%
config = tiledb.Config(
        {"vfs.s3.aws_access_key_id": creds.access_key, "vfs.s3.aws_secret_access_key": creds.secret_key}
    )
ctx = tiledb.Ctx(config=config)

# %%
config_dict = config.dict()

# %%
storage.create_mbes_array(array_uri, required_attributes, ctx)

# %%
files = fs.glob(survey_uri + "**.gsf")
len(files)
# Out:
# 491

# %%
# probably worth chunking into 4 blocks rather than submit everything at once

# %%
n_partitions = 4
files_blocks = scatter(files, n_partitions)
len(files_blocks[0])
# Out:
# 123

# %%
size_limit_mb = 500
processing_node_limit = 30
ping_slice_step = 1000
slices_per_node = 5
local_tasks_limit = 1
local_ping_slice_step = 1000
local_slices_per_task = 4

# %%
def ingest_gsfs(files, size_limit_mb, processing_node_limit, ping_slice_step, slices_per_node):
    """
    Prototype ingester.
    """

    node_counter = 0
    skipped_files = []
    large_files = []
    tasks = []
    tasks_dict = {n: [] for n in range(processing_node_limit)}

    for pathname in files:
        metadata_pathname = pathname.replace(".gsf", ".json")
        base_name = Path(pathname).stem
        with fs.open(metadata_pathname) as src:
            gsf_metadata = json.loads(src.read())

        if (gsf_metadata["size"] / 1024 / 1024) > size_limit_mb:
            large_files.append(pathname)
            continue

        ping_count = gsf_metadata["file_record_types"]["GSF_SWATH_BATHYMETRY_PING"]["record_count"]
        if ping_count == 0:
            skipped_files.append(pathname)
            continue

        slices = [slice(start, start+ping_slice_step) for start in numpy.arange(0, ping_count, ping_slice_step)]
        slice_chunks = [slices[i:i+slices_per_node] for i in range(0, len(slices), slices_per_node)]

        for slice_chunk in slice_chunks:
            start_idx = slice_chunk[0].start
            end_idx = slice_chunk[0].stop
            task_name = f"{base_name}-{start_idx}-{end_idx}-{node_counter}"
            task = Delayed("sixy6e/ingest_gsf_slices", name=task_name, image_name="3.7-geo")(gsf_metadata["gsf_uri"], creds.access_key, creds.secret_key, array_uri, slice_chunk)
            task.set_timeout(1800)

            if len(tasks_dict[node_counter]):
                task.depends_on(tasks_dict[node_counter][-1])

            tasks.append(task)
            tasks_dict[node_counter].append(task)
            node_counter += 1

            if node_counter == processing_node_limit:
                node_counter = 0

    reduce_task = Delayed(reduce_region_codes, "reduce-region_codes-timestamps", local=True)(tasks)
    
    return reduce_task, skipped_files, large_files

# %%
skipped_files = []
large_files = []

# %%
reduce_task, skipped_files1, large_files1 = ingest_gsfs(files_blocks[0], size_limit_mb, processing_node_limit, ping_slice_step, slices_per_node)

# %%
cell_count_df1, start_end_timestamps1 = reduce_task.compute()

# %%
reduce_task, skipped_files2, large_files2 = ingest_gsfs(files_blocks[1], size_limit_mb, processing_node_limit, ping_slice_step, slices_per_node)

# %%
cell_count_df2, start_end_timestamps2 = reduce_task.compute()

# %%
reduce_task, skipped_files3, large_files3 = ingest_gsfs(files_blocks[2], size_limit_mb, processing_node_limit, ping_slice_step, slices_per_node)

# %%
cell_count_df3, start_end_timestamps3 = reduce_task.compute()

# %%
reduce_task, skipped_files4, large_files4 = ingest_gsfs(files_blocks[3], size_limit_mb, processing_node_limit, ping_slice_step, slices_per_node)

# %%
cell_count_df4, start_end_timestamps4 = reduce_task.compute()

# %%
large_files.extend(large_files1)
large_files.extend(large_files2)
large_files.extend(large_files3)
large_files.extend(large_files4)

# %%
skipped_files.extend(skipped_files1)
skipped_files.extend(skipped_files2)
skipped_files.extend(skipped_files3)
skipped_files.extend(skipped_files4)

# %%
len(large_files)
# Out:
# 0

# %%
len(skipped_files)
# Out:
# 0

# %%
# local compute

# %%
# reduce_task, skipped_files_local, large_files_local = ingest_gsfs(large_files, size_limit_mb, local_tasks_limit, local_ping_slice_step, local_slices_per_task)

# %%
# cell_count_df_local, start_end_timestamps_local = reduce_task.compute()

# %%
# collect and reduce dataframes and ping start end times

# %%
local_non_local_results = [
    [cell_count_df1, start_end_timestamps1],
    [cell_count_df2, start_end_timestamps2],
    [cell_count_df3, start_end_timestamps3],
    [cell_count_df4, start_end_timestamps4],
    # [cell_count_df_local, start_end_timestamps_local],
]

# %%
final_cell_count_df, final_start_end_timestamps = reduce_region_codes(local_non_local_results)

# %%
final_cell_count_df
# Out:
#                region_code  count
# 0         R770050644787754      1
# 1         R770050644787755      1
# 2         R770050644787782      1
# 3         R770050644787785      1
# 4         R770050644787788      1
# ...                    ...    ...
# 96230420  S522852555853033      1
# 96230421  S522852555853060      1
# 96230422  S522852555853306      1
# 96230423  S522852555853333      1
# 96230424  S522852555853366      1
#
# [96230425 rows x 2 columns]

# %%
final_start_end_timestamps
# Out:
# [datetime.datetime(2000, 4, 4, 23, 27, 15, 849000),
#  datetime.datetime(2000, 5, 15, 14, 17, 55, 377000)]

# %%
# cell density, coverage geometry

# %%
final_cell_count_df["geometry"] = rhealpix.rhealpix_geo_boundary(final_cell_count_df.region_code.values)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1331/917390098.py in <module>
# ----> 1 final_cell_count_df["geometry"] = rhealpix.rhealpix_geo_boundary(final_cell_count_df.region_code.values)
#
# ~/.local/lib/python3.7/site-packages/bathy_datasets-0.0.post51+g9708c1b-py3.7.egg/bathy_datasets/rhealpix.py in rhealpix_geo_boundary(region_codes, shapely_geometries, round_coords, decimals)
#     449     polygons = []
#     450     for i in range(ncodes):
# --> 451         polygons.append(Polygon(boundary[i]))
#     452
#     453     if shapely_geometries:
#
# /opt/conda/lib/python3.7/site-packages/shapely/geometry/polygon.py in __init__(self, shell, holes)
#     259
#     260         if shell is not None:
# --> 261             ret = geos_polygon_from_py(shell, holes)
#     262             if ret is not None:
#     263                 geom, n = ret
#
# /opt/conda/lib/python3.7/site-packages/shapely/geometry/polygon.py in geos_polygon_from_py(shell, holes)
#     537
#     538     if shell is not None:
# --> 539         ret = geos_linearring_from_py(shell)
#     540         if ret is None:
#     541             return None
#
# /opt/conda/lib/python3.7/site-packages/shapely/speedups/_speedups.pyx in shapely.speedups._speedups.geos_linearring_from_py()
#
# /opt/conda/lib/python3.7/site-packages/shapely/speedups/_speedups.pyx in shapely.speedups._speedups.required()
#
# /opt/conda/lib/python3.7/site-packages/numpy/core/_asarray.py in require(a, dtype, requirements, like)
#      20
#      21
# ---> 22 @set_array_function_like_doc
#      23 @set_module('numpy')
#      24 def require(a, dtype=None, requirements=None, *, like=None):
#
# KeyboardInterrupt:

# %%
gdf_15 = geopandas.GeoDataFrame(final_cell_count_df, crs="epsg:4326")

# %%
with fiona.Env(session=AWSSession(aws_access_key_id=creds.access_key, aws_secret_access_key=creds.secret_key)):
    gdf_15.to_file(soundings_cell_density_uri_15, driver="GeoJSONSeq", coordinate_precision=11)

# %%
resolution12_df = pandas.DataFrame(
    {
        "region_code": final_cell_count_df.region_code.str[0:13],
        "count": final_cell_count_df["count"],
    }
).groupby(
    ["region_code"]
)["count"].agg("sum").to_frame("count").reset_index()

# %%
resolution12_df
# Out:
#            region_code  count
# 0        R770050644787     15
# 1        R770050644788     54
# 2        R770050644864     18
# 3        R770050644865     39
# 4        R770050644866     94
# ...                ...    ...
# 6310331  S522852555833      7
# 6310332  S522852555840      8
# 6310333  S522852555843      6
# 6310334  S522852555850      9
# 6310335  S522852555853      6
#
# [6310336 rows x 2 columns]

# %%
resolution12_df["geometry"] = rhealpix.rhealpix_geo_boundary(resolution12_df.region_code.values)

# %%
gdf = geopandas.GeoDataFrame(resolution12_df, crs="epsg:4326")

# %%
final_cell_count_df = None
gdf_15 = None

# %%
with fiona.Env(session=AWSSession(aws_access_key_id=creds.access_key, aws_secret_access_key=creds.secret_key)):
    gdf.to_file(soundings_cell_density_uri, driver="GeoJSONSeq", coordinate_precision=11)

# %%
dissolved = geopandas.GeoDataFrame(geometry.dissolve(gdf), crs="epsg:4326")
# Out:
# /opt/conda/lib/python3.7/site-packages/geopandas/_vectorized.py:142: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   aout[:] = out

# %%
dissolved
# Out:
#                                             geometry
# 0  MULTIPOLYGON (((-84.73944 -74.51995, -84.73989...

# %%
with fiona.Env(session=AWSSession(aws_access_key_id=creds.access_key, aws_secret_access_key=creds.secret_key)):
    dissolved.to_file(coverage_uri, driver="GeoJSONSeq", coordinate_precision=11)

# %%
dggs = rhealpix.RhealpixDGGS.from_ellipsoid()

# %%
dggs.cell_width(12)
# Out:
# 18.8309796906348

# %%
area_ha = gdf.shape[0] * dggs.cell_width(12) **2 / 10000
sonar_metadata["area_ha"] = area_ha
area_ha
# Out:
# 223768.17209959155

# %%
with fs.open(asb_metadata_uri) as src:
    asb_metadata = json.loads(src.read())

# %%
tiledb.cloud.register_array(
    uri=array_uri,
    namespace="sixy6e", # Optional, you may register it under your username, or one of your organizations
    array_name=array_name,
    description=asb_metadata["survey_general"]["abstract"],  # Optional 
    access_credentials_name="AusSeabedGMRT-PL019"
)

# %%
with tiledb.open(array_uri, ctx=ctx) as ds:
    schema = ds.schema
    domain = ds.domain
    non_empty_domain = ds.nonempty_domain()

# %%
gdf["count"].max()
# Out:
# 26850

# %%
gdf2 = geopandas.GeoDataFrame({"region_code": gdf.region_code.str[0:9], "count": gdf["count"]}).groupby(["region_code"])["count"].agg("sum").to_frame("count").reset_index()

# %%
gdf2
# Out:
#      region_code   count
# 0      R77005064  188744
# 1      R77005065   48072
# 2      R77005067   34186
# 3      R77005068   28793
# 4      R77005076   79731
# ...          ...     ...
# 6544   S52285244    2362
# 6545   S52285245    2371
# 6546   S52285253    2384
# 6547   S52285254    2373
# 6548   S52285255    2394
#
# [6549 rows x 2 columns]

# %%
gdf2["count"].max()
# Out:
# 1858269

# %%
dggs.cell_width(8)
# Out:
# 1525.3093549414189

# %%
full_idx = (slice(*non_empty_domain[0]), slice(*non_empty_domain[1]))
full_idx
# Out:
# (slice(130.75923620980248, 150.4261983572004, None),
#  slice(-43.25960525884236, -31.820635024132443, None))

# %%
slices = []
for geom in rhealpix.rhealpix_geo_boundary(gdf2.region_code.values, round_coords=False):
    bounds = geom.bounds
    slices.append((
        slice(bounds[0], bounds[-2]),
        slice(bounds[1], bounds[-1])
    ))

# %%
n_partitions = 3
n_sub_partitions = 2
blocks = scatter(slices, n_partitions)

# %%
len(blocks), len(blocks[0])
# Out:
# (3, 2183)

# %%
len(scatter(blocks[0], n_sub_partitions)[0])
# Out:
# 1092

# %%
stats_attrs = [at for at in required_attributes if at not in ["timestamp", "region_code"]]
stats_attrs.insert(0, "Y")
stats_attrs.insert(0, "X")

# %%
stats_results = []
tasks_dict = {stat: [] for stat in stats_attrs}
reduce_tasks = []

for i, block in enumerate(blocks):
    sub_tasks = []
    sub_blocks = scatter(block, n_sub_partitions)

    for si, sub_block in enumerate(sub_blocks):
        for attribute in stats_attrs:
            
            if attribute in ["X", "Y"]:
                schema = attribute
            else:
                schema = None

            task_name = f"block-{i}-sub_block-{si}-{attribute}"
            task = Delayed("sixy6e/basic_statistics_incremental", name=task_name)(array_uri, config_dict, attribute, schema=schema, idxs=sub_block, summarise=False)

            if len(tasks_dict[attribute]) > 1:
                task.depends_on(tasks_dict[attribute][-1])

            tasks_dict[attribute].append(task)

for attribute in stats_attrs:
    task_name = f"reduce-attibute-{attribute}"
    reducer_task = Delayed("sixy6e/basic_statistics_reduce", name=task_name)(tasks_dict[attribute], attribute)
    reduce_tasks.append(reducer_task)

collect_stats_task = Delayed(gather_stats, local=True, name="gather-stats")(reduce_tasks)

# %%
stats_tasks = []

for i in range(domain.ndim):
    attribute = domain.dim(i).name
    name = f"{attribute}_basic_stats"
    
    stats_tasks.append(
        DelayedArrayUDF(tiledb_array_uri, "sixy6e/basic-statistics", attrs=[attribute], name=name, attribute=attribute)(non_empty_domain)
    )

for i in range(schema.nattr):
    attribute = schema.attr(i).name
    name = f"{attribute}_basic_stats"
    
    if attribute in ["timestamp", "region_code"]:
        continue
        
    stats_tasks.append(
        DelayedArrayUDF(tiledb_array_uri, "sixy6e/basic-statistics", attrs=[attribute], name=name, attribute=attribute)(non_empty_domain)
    )

stats_report = Delayed(gather_stats, local=True, name="stats-report")(stats_tasks)

# %%
stats_results = collect_stats_task.compute()

# %%
json.dumps(stats_results, cls=stac_metadata.Encoder)
# Out:
# '{"X": {"minimum": 0.0, "maximum": 150.4261983572004, "count": 100549439, "total": 14851623775.17089, "mean": 147.70469057685037, "variance": 32.80644275174163, "stddev": 5.727690874317645, "skewness": -2.411479368684281, "kurtosis": 3.873487893544474}, "Y": {"minimum": -38.89102137088019, "maximum": 4.67519989605205e-310, "count": 100549439, "total": -3722422908.57374, "mean": -37.02082225017426, "variance": 3.309265079513288, "stddev": 1.8191385542374963, "skewness": 2.2264229286019663, "kurtosis": 3.3839705276359267}, "Z": {"minimum": -1.5, "maximum": 1491.449951171875, "count": 100549439, "total": 11520319464.67021, "mean": 114.57368215321628, "variance": 8387.084974906242, "stddev": 91.58102955801623, "skewness": 2.7574490945491448, "kurtosis": 10.649889832616607}, "across_track": {"minimum": -1758.199951171875, "maximum": 1.2040134350044817e+20, "count": 100549439, "total": -8502072.537223876, "mean": -0.08455614095692643, "variance": 22221.632582763996, "stddev": 149.06922077600055, "skewness": 1.786550490520258, "kurtosis": 98.99931854327984}, "along_track": {"minimum": -2.8664378087283098e+17, "maximum": 1803.9000244140625, "count": 100549439, "total": -194056850.36950108, "mean": -1.9299645259035316, "variance": 21646.905727619276, "stddev": 147.1288745543147, "skewness": -73.05323130746515, "kurtosis": 13281.536429306443}, "beam_angle": {"minimum": NaN, "maximum": NaN, "count": 16056964, "total": 13972967.299493883, "mean": 0.8702122829380375, "variance": 2631.712923864404, "stddev": 51.30022342899107, "skewness": 0.0013667131378654754, "kurtosis": -1.5864971398335426}, "beam_angle_forward": {"minimum": NaN, "maximum": NaN, "count": 0, "total": 0.0, "mean": NaN, "variance": NaN, "stddev": NaN, "skewness": NaN, "kurtosis": NaN}, "beam_flags": {"minimum": 0, "maximum": 208, "count": 100549439, "total": 24148980.0, "mean": 0.24017021119332152, "variance": 1.0743496584565366, "stddev": 1.0365083976777691, "skewness": 4.313507877895494, "kurtosis": 16.838537972505375}, "beam_number": {"minimum": 0, "maximum": 50864, "count": 100549439, "total": 5499486867.0, "mean": 54.694356544346306, "variance": 1018.7096584105421, "stddev": 31.91723137132264, "skewness": 0.006636210163214951, "kurtosis": -1.1944803134883462}, "centre_beam": {"minimum": 0, "maximum": 96, "count": 100549439, "total": 894631.0, "mean": 0.008897424082097564, "variance": 0.008818260014501611, "stddev": 0.0939055909650837, "skewness": 10.459496038794985, "kurtosis": 107.40105738556795}, "course": {"minimum": 0.0, "maximum": 360.0, "count": 100549439, "total": 16990925332.024372, "mean": 168.98080686481376, "variance": 10610.954127208295, "stddev": 103.00948561762793, "skewness": 0.12368618929487174, "kurtosis": -1.1043253105268787}, "depth_corrector": {"minimum": 0.0, "maximum": 8.531982166014038e+26, "count": 100549439, "total": 10053938190.813225, "mean": 99.98999786376953, "variance": 0.0003272033678312985, "stddev": 0.018088763579396424, "skewness": -10826.034237584043, "kurtosis": 79788856.03116265}, "gps_tide_corrector": {"minimum": 0.0, "maximum": 1.1217250699880516e+21, "count": 100549439, "total": 0.0, "mean": 0.0, "variance": 0.0, "stddev": 0.0, "skewness": NaN, "kurtosis": NaN}, "heading": {"minimum": -9.299595244631763e-36, "maximum": 359.9599914550781, "count": 100549439, "total": 4692558761.101587, "mean": 46.66916899557826, "variance": 8026.707779504593, "stddev": 89.5918957244716, "skewness": 1.9647671685032082, "kurtosis": 2.7615636864004998}, "heave": {"minimum": -4.639999866485596, "maximum": 1.8596767984496518e+22, "count": 100549439, "total": 7206966716.98019, "mean": 71.67585208486534, "variance": 1958.5385343540759, "stddev": 44.255378592370846, "skewness": -1.0023523317458458, "kurtosis": -0.995002121317285}, "height": {"minimum": -6071091200.0, "maximum": 0.0, "count": 100549439, "total": 0.0, "mean": 0.0, "variance": 0.0, "stddev": 0.0, "skewness": NaN, "kurtosis": NaN}, "horizontal_error": {"minimum": 0.0, "maximum": 83.4599990844 ...

# %%
crs_info = {
    "horizontal_datum": "epsg:4326",
    "vertical_data": "epsg:5714",  # MSL
}

# %%
with tiledb.open(array_uri, "w", ctx=ctx) as ds:
    ds.meta["crs_info"] = json.dumps(crs_info)
    ds.meta["basic_statistics"] = json.dumps(stats_results, cls=stac_metadata.Encoder)

# %%
dataset_metadata = stac_metadata.prepare(
    uid,
    sonar_metadata,
    stats_results,
    asb_metadata,
    array_uri,
    coverage_uri,
    soundings_cell_density_uri,
    creds.access_key,
    creds.secret_key,
    final_start_end_timestamps,
    outdir_uri,
    stac_md_uri,
)

# %%
dataset_metadata
# Out:
# {'type': 'Feature',
#  'stac_version': '1.0.0',
#  'id': '706f772a-d0d8-424d-ac4c-1d5f656bc71e',
#  'properties': {'sonar:processed_datetime': datetime.datetime(2000, 4, 4, 23, 27, 12, 432000, tzinfo=datetime.timezone.utc),
#   'sonar:platform_type': 'surface_ship',
#   'sonar:full_raw_data': False,
#   'sonar:roll_compensated': True,
#   'sonar:pitch_compensated': True,
#   'sonar:heave_compensated': True,
#   'sonar:tide_compensated': True,
#   'sonar:number_of_receivers': 1,
#   'sonar:number_of_transmitters': 1,
#   'sonar:depth_calculation': 'corrected',
#   'sonar:ray_tracing': True,
#   'sonar:msb_applied_to_attitude': False,
#   'sonar:heave_removed_from_gps_tc': False,
#   'sonar:utc_offset': 'unknown',
#   'sonar:roll_reference': 'unknown',
#   'sonar:draft_to_apply': 0.0,
#   'sonar:pitch_to_apply': 0.0,
#   'sonar:roll_to_apply': 0.0,
#   'sonar:gyro_to_apply': 0.0,
#   'sonar:position_offset_to_apply': [0.0, 0.0, 0.0],
#   'sonar:antenna_offset_to_apply': [0.0, 0.0, 0.0],
#   'sonar:transducer_offset_to_apply': [0.0, 0.0, 0.0],
#   'sonar:transducer_pitch_offset_to_apply': 0.0,
#   'sonar:transducer_roll_offset_to_apply': 0.0,
#   'sonar:transducer_heading_offset_to_apply': 0.0,
#   'sonar:mru_pitch_to_apply': 0.0,
#   'sonar:mru_roll_to_apply': 0.0,
#   'sonar:mru_heading_to_apply': 0.0,
#   'sonar:mru_offset_to_apply': [0.0, 0.0, 0.0],
#   'sonar:center_of_rotation_offset_to_apply': ['unknown',
#    'unknown',
#    'unknown'],
#   'sonar:position_latency_to_apply': 0.0,
#   'sonar:attitude_latency_to_apply': 0.0,
#   'sonar:depth_sensor_latency_to_apply': 0.0,
#   'sonar:depth_sensor_offset_to_apply': [0.0, 0.0, 0.0],
#   'sonar:rx_transducer_offset_to_apply': [0.0, 0.0, 0.0],
#   'sonar:rx_transducer_pitch_offset_to_apply': 0.0,
#   'sonar:rx_transducer_roll_offset_to_apply': 0.0,
#   'sonar:rx_transducer_heading_offset_to_apply': 0.0,
#   'sonar:applied_draft': 0.0,
#   'sonar:applied_pitch_bias': 0.0,
#   'sonar:applied_roll_bias': 0.0,
#   'sonar:applied_gyro_bias': -30.0,
#   'sonar:applied_position_offset': [0.0, 0.0, 0.0],
#   'sonar:applied_antenna_offset': [0.0, 0.0, 0.0],
#   'sonar:applied_transducer_offset': [0.0, 0.0, 0.0],
#   'sonar:applied_transducer_pitch_offset': 'unknown',
#   'sonar:applied_transducer_roll_offset': 'unknown',
#   'sonar:applied_transducer_heading_offset': 'unknown',
#   'sonar:applied_mru_roll': 0.0,
#   'sonar:applied_mru_pitch': 0.0,
#   'sonar:applied_mru_heading': 0.0,
#   'sonar:applied_mru_offset': [0.0, 0.0, 0.0],
#   'sonar:applied_center_of_rotation_offset': [0.0, 0.0, 0.0],
#   'sonar:applied_position_latency': 0.0,
#   'sonar:applied_attitude_latency': 0.0,
#   'sonar:applied_depth_sensor_latency': 0.0,
#   'sonar:applied_depth_sensor_offset': [0.0, 0.0, 0.0],
#   'sonar:applied_rx_transducer_offset': ['unknown', 'unknown', 'unknown'],
#   'sonar:applied_rx_transducer_pitch_offset': 'unknown',
#   'sonar:applied_rx_transducer_roll_offset': 'unknown',
#   'sonar:applied_rx_transducer_heading_offset': 'unknown',
#   'sonar:geoid': 'wgs-84',
#   'sonar:tidal_datum': 'unknown',
#   'sonar:processing_timestamp': datetime.datetime(2021, 9, 29, 14, 41, 37, tzinfo=datetime.timezone.utc),
#   'sonar:machine_name': '26Q5HD2',
#   'sonar:operator_name': 'jc146255',
#   'sonar:command': 'HIPStoGSF',
#   'sonar:comment': 'version 11.3.22',
#   'sonar:area_ha': 223768.17209959155,
#   'sonar:horizontal_datum': 'epsg:4326',
#   'sonar:vertical_data': 'epsg:5714',
#   'processing:lineage': "The Bioview (SS01/2000) bathymetry survey was acquired by CSIRO onboard the RV Southern Surveyor from the 04th of April 2000 to the 15th of May 2000 using a Simrad EM1002 multibeam sonar system. The data were processed using CARIS HIPS&SIPS 11.4.1 and the following processing steps were performed. Import into CARIS HIPS&SIPS. (***check with CSIRO team - apply MSL predicted tides ********). Georeferenced bathymetry and computed TPU. Generated CUBE surfaces as per AusSeabed requirements. Manually removed any erroneous soundings that were not eliminated using CUBE.\nConverted GSF's to TileDB sparse array",
#   'title': 'Bioview (SS01/2000)',
#   'description': 'The Bioview (SS01/2000) bathymetry survey,  SurveyID GA-0224 was acquired by CSIRO onboard the RV Southern Surveyor from the 04th of April 2000 to the 15th of May 2000 using a Simrad EM1002 multibeam sonar system. The objectives of the Bioview (SS01/2000) bathymetry survey were to (*****check with CSIRO team************).',
#   'start_datetime': '2000-04-04T23:27:15.849000Z',
#   'end_datetime': '2000-05-15T14:17:55.377000Z',
#   'created': '2022-04-12T09:19:28.021162Z',
#   'instruments': ['Simrad EM1002 '],
#   'providers': [{'name': 'CSIRO',
#     'roles': [<ProviderRole.PRODUCER: 'producer'>]},
#    {'name': 'CSIRO', 'roles': [<ProviderRole.HOST: 'host'>]}],
#   'proj:epsg': 4326,
#   'pc:count': 100549439,
#   'pc:type': <PhenomenologyType.SONAR: 'sonar'>,
#   'pc:encoding': 'TileDB',
#   'pc:schemas': [{'name': 'X', 'size': 8, 'type': 'floating'},
#    {'name': 'Y', 'size': 8, 'type': 'floating'},
#    {'name': 'Z', 'size': 4, 'type': 'floating'},
#    {'name': 'timestamp', 'size': 8, 'type': 'other'},
#    {'name': 'across_track', 'size': 4, 'type': 'floating'},
#    {'name': 'along_track', 'size': 4, 'type': 'floating'},
#    {'name': 'travel_time', 'size': 4, 'type': 'floating'},
#    {'name': 'beam_angle', 'size': 4, 'type': 'floating'},
#    {'name': 'beam_angle_forward', 'size': 4, 'type': 'floating'},
#    {'name': 'vertical_error', 'size': 4, 'type': 'floating'},
#    {'name': 'horizontal_error', 'size': 4, 'type': 'floating'},
#    {'name': 'sector_number', 'size': 1, 'type': 'unsigned'},
#    {'name': 'beam_flags', 'size': 1, 'type': 'unsigned'},
#    {'name': 'ping_flags', 'size': 1, 'type': 'unsigned'},
#    {'name': 'tide_corrector', 'size': 4, 'type': 'floating'},
#    {'name': 'depth_corrector', 'size': 4, 'type': 'floating'},
#    {'name': 'heading', 'size': 4, 'type': 'floating'},
#    {'name': 'pitch', 'size': 4, 'type': 'floating'},
#    {'name': 'roll', 'size': 4, 'type': 'floating'},
#    {'name': 'heave', 'size': 4, 'type': 'floating'},
#    {'name': 'course', 'size': 4, 'type': 'floating'},
#    {'name': 'speed', 'size': 4, 'type': 'floating'},
#    {'name': 'height', 'size': 4, 'type': 'floating'},
#    {'name': 'separation', 'size': 4, 'type': 'floating'},
#    {'name': 'gps_tide_corrector', 'size': 4, 'type': 'floating'},
#    {'name': 'centre_beam', 'size': 1, 'type': 'unsigned'},
#    {'name': 'beam_number', 'size': 2, 'type': 'unsigned'},
#    {'name': 'region_code', 'size': 0, 'type': 'other'}],
#   'pc:statistics': [{'minimum': 0.0,
#     'maximum': 150.4261983572004,
#     'count': 100549439,
#     'total': 14851623775.17089,
#     'mean': 147.70469057685037,
#     'variance': 32.80644275174163,
#     'stddev': 5.727690874317645,
#     'skewness': -2.411479368684281,
#     'kurtosis': 3.873487893544474,
#     'name': 'X'},
#    {'minimum': -38.89102137088019,
#     'maximum': 4.67519989605205e-310,
#     'count': 100549439,
#     'total': -3722422908.57374,
#     'mean': -37.02082225017426,
#     'variance': 3.309265079513288,
#     'stddev': 1.8191385542374963,
#     'skewness': 2.2264229286019663,
#     'kurtosis': 3.3839705276359267,
#     'name': 'Y'},
#    {'minimum': -1.5,
#     'maximum': 1491.449951171875,
#     'count': 100549439,
#     'total': 11520319464.67021,
#     'mean': 114.57368215321628,
#     'variance': 8387.084974906242,
#     'stddev': 91.58102955801623,
#     'skewness': 2.7574490945491448,
#     'kurtosis': 10.649889832616607,
#     'name': 'Z'},
#    {'minimum': -1758.199951171875,
#     'maximum': 1.2040134350044817e+20,
#     'count': 100549439,
#     'total': -8502072.537223876,
#     'mean': -0.08455614095692643,
#     'variance': 22221.632582763996,
#     'stddev': 149.06922077600055,
#     'skewness': 1.786550490520258,
#     'kurtosis': 98.99931854327984,
#     'name': 'across_track'},
#    {'minimum': -2.8664378087283098e+17,
#     'maximum': 1803.9000244140625,
#     'count': 100549439,
#     'total': -194056850.36950108,
#     'mean': -1.9299645259035316,
#     'variance': 21646.905727619276,
#     'stddev': 147.1288745543147,
#     'skewness': -73.05323130746515,
#     'kurtosis': 13281.536429306443,
#     'name': 'along_track'},
#    {'minimum': nan,
#     'maximum': nan,
#     'count': 16056964,
#     'total': 13972967.299493883,
#     'mean': 0.8702122829380375,
#     'variance': 2631.712923864404,
#     'stddev': 51.30022342899107,
#     'skewness': 0.0013667131378654754,
#     'kurtosis': -1.5864971398335426,
#     'name': 'beam_angle'},
#    {'minimum': nan,
#     'maximum': nan,
#     'count': 0,
#     'total': 0.0,
#     'mean': nan,
#     'variance': nan,
#     'stddev': nan,
#     'skewness': nan,
#     'kurtosis': nan,
#     'name': 'beam_angle_forward'},
#    {'minimum': 0,
#     'maximum': 208,
#     'count': 100549439,
#     'total': 24148980.0,
#     'mean': 0.24017021119332152,
#     'variance': 1.0743496584565366,
#     'stddev': 1.0365083976777691,
#     'skewness': 4.313507877895494,
#     'kurtosis': 16.838537972505375,
#     'name': 'beam_flags'},
#    {'minimum': 0,
#     'maximum': 50864,
#     'count': 100549439,
#     'total': 5499486867.0,
#     'mean': 54.694356544346306,
#     'variance': 1018.7096584105421,
#     'stddev': 31.91723137132264,
#     'skewness': 0.006636210163214951,
#     'kurtosis': -1.1944803134883462,
#     'name': 'beam_number'},
#    {'minimum': 0,
#     'maximum': 96,
#     'count': 100549439,
#     'total': 894631.0,
#     'mean': 0.008897424082097564,
#     'variance': 0.008818260014501611,
#     'stddev': 0.0939055909650837,
#     'skewness': 10.459496038794985,
#     'kurtosis': 107.40105738556795,
#     'name': 'centre_beam'},
#    {'minimum': 0.0,
#     'maximum': 360.0,
#     'count': 100549439,
#     'total': 16990925332.024372,
#     'mean': 168.98080686481376,
#     'variance': 10610.954127208295,
#     'stddev': 103.00948561762793,
#     'skewness': 0.12368618929487174,
#     'kurtosis': -1.1043253105268787,
#     'name': 'course'},
#    {'minimum': 0.0,
#     'maximum': 8.531982166014038e+26,
#     'count': 100549439,
#     'total': 10053938190.813225,
#     'mean': 99.98999786376953,
#     'variance': 0.0003272033678312985,
#     'stddev': 0.018088763579396424,
#     'skewness': -10826.034237584043,
#     'kurtosis': 79788856.03116265,
#     'name': 'depth_corrector'},
#    {'minimum': 0.0,
#     'maximum': 1.1217250699880516e+21,
#     'count': 100549439,
#     'total': 0.0,
#     'mean': 0.0,
#     'variance': 0.0,
#     'stddev': 0.0,
#     'skewness': nan,
#     'kurtosis': nan,
#     'name': 'gps_tide_corrector'},
#    {'minimum': -9.299595244631763e-36,
#     'maximum': 359.9599914550781,
#     'count': 100549439,
#     'total': 4692558761.101587,
#     'mean': 46.66916899557826,
#     'variance': 8026.707779504593,
#     'stddev': 89.5918957244716,
#     'skewness': 1.9647671685032082,
#     'kurtosis': 2.7615636864004998,
#     'name': 'heading'},
#    {'minimum': -4.639999866485596,
#     'maximum': 1.8596767984496518e+22,
#     'count': 100549439,
#     'total': 7206966716.98019,
#     'mean': 71.67585208486534,
#     'variance': 1958.5385343540759,
#     'stddev': 44.255378592370846,
#     'skewness': -1.0023523317458458,
#     'kurtosis': -0.995002121317285,
#     'name': 'heave'},
#    {'minimum': -6071091200.0,
#     'maximum': 0.0,
#     'count': 100549439,
#     'total': 0.0,
#     'mean': 0.0,
#     'variance': 0.0,
#     'stddev': 0.0,
#     'skewness': nan,
#     'kurtosis': nan,
#     'name': 'height'},
#    {'minimum': 0.0,
#     'maximum': 83.45999908447266,
#     'count': 100549439,
#     'total': 224713151.97700334,
#     'mean': 2.23485236926089,
#     'variance': 0.04017564128482911,
#     'stddev': 0.20043862223840272,
#     'skewness': 175.88857967505558,
#     'kurtosis': 52464.04558613934,
#     'name': 'horizontal_error'},
#    {'minimum': 0,
#     'maximum': 105,
#     'count': 100549439,
#     'total': 5757811.0,
#     'mean': 0.057263482096603244,
#     'variance': 2.64417591963951,
#     'stddev': 1.6260922235960389,
#     'skewness': 43.00840565896817,
#     'kurtosis': 2312.0377826841254,
#     'name': 'ping_flags'},
#    {'minimum': -9.449999809265137,
#     'maximum': 99.0,
#     'count': 100549439,
#     'total': 7204262518.730442,
#     'mean': 71.64895786967486,
#     'variance': 1962.4717307036808,
#     'stddev': 44.29979379978739,
#     'skewness': -1.0024822954892103,
#     'kurtosis': -0.9945468363608017,
#     'name': 'pitch'},
#    {'minimum': -17.139999389648438,
#     'maximum': 99.0,
#     'count': 100549439,
#     'total': 7191847808.72851,
#     'mean': 71.52548915492716,
#     'variance': 1981.8809357135572,
#     'stddev': 44.51832134878355,
#     'skewness': -1.0053137723855032,
#     'kurtosis': -0.9845205087678415,
#     'name': 'roll'},
#    {'minimum': 0,
#     'maximum': 160,
#     'count': 100549439,
#     'total': 0.0,
#     'mean': 0.0,
#     'variance': 0.0,
#     'stddev': 0.0,
#     'skewness': nan,
#     'kurtosis': nan,
#     'name': 'sector_number'},
#    {'minimum': 0.0,
#     'maximum': 1.2837677587640428e-09,
#     'count': 100549439,
#     'total': 0.0,
#     'mean': 0.0,
#     'variance': 0.0,
#     'stddev': 0.0,
#     'skewness': nan,
#     'kurtosis': nan,
#     'name': 'separation'},
#    {'minimum': 0.0,
#     'maximum': 650.3599853515625,
#     'count': 100549439,
#     'total': 935866607.086406,
#     'mean': 9.307526888204777,
#     'variance': 31.49141802731331,
#     'stddev': 5.611721485187349,
#     'skewness': 31.059558408772897,
#     'kurtosis': 2350.459762619086,
#     'name': 'speed'},
#    {'minimum': -1.5,
#     'maximum': 0.0,
#     'count': 100549439,
#     'total': -12305727.930797279,
#     'mean': -0.12238484921628731,
#     'variance': 0.12850447415524519,
#     'stddev': 0.3584752071695408,
#     'skewness': -2.825947077325959,
#     'kurtosis': 6.568713480606938,
#     'name': 'tide_corrector'},
#    {'minimum': nan,
#     'maximum': nan,
#     'count': 16056964,
#     'total': 3379779.8395450693,
#     'mean': 0.21048685414908255,
#     'variance': 0.03500857865585457,
#     'stddev': 0.18710579535614222,
#     'skewness': 2.2285294377124987,
#     'kurtosis': 5.6975540741901955,
#     'name': 'travel_time'},
#    {'minimum': 0.0,
#     'maximum': 5.228514032324161e+32,
#     'count': 100549439,
#     'total': 60640192.3088249,
#     'mean': 0.6030883206501519,
#     'variance': 0.004647892312092648,
#     'stddev': 0.06817545241575335,
#     'skewness': 8.292799271884105,
#     'kurtosis': 98.27834648664005,
#     'name': 'vertical_error'}],
#   'sci:citation': 'Kloser, R. et al. 2000, Bioview survey.',
#   'datetime': '2000-05-15T14:17:55.377000Z'},
#  'geometry': {'type': 'MultiPolygon',
#   'coordinates': [[[(-84.7394398596, -74.51995128225),
#      (-84.73995104025, -74.51995128225),
#      (-84.74040247414, -74.52012829089),
#      (-84.73989128768, -74.52012829089),
#      (-84.7394398596, -74.51995128225)]],
#    [[(-84.73582880412, -74.51853521168),
#      (-84.73537746832, -74.51835820268),
#      (-84.73588859673, -74.51835820268),
#      (-84.73633993832, -74.51853521168),
#      (-84.73582880412, -74.51853521168)]],
#    [[(-84.40143163439, -74.37514477408),
#      (-84.40098817677, -74.37496773252),
#      (-84.4014946455, -74.37496773252),
#      (-84.40193810882, -74.37514477408),
#      (-84.40143163439, -74.37514477408)]],
#    [[(-84.3969975073, -74.37337435671),
#      (-84.39750392474, -74.37337435671),
#      (-84.39794729823, -74.37355139863),
#      (-84.3974408751, -74.37355139863),
#      (-84.3969975073, -74.37337435671)]],
#    [[(-84.32194381169, -74.36664673387),
#      (-84.32150148765, -74.36646969038),
#      (-84.32200768292, -74.36646969038),
#      (-84.32245001265, -74.36664673387),
#      (-84.32194381169, -74.36664673387)]],
#    [[(-84.3192900167, -74.3655844723),
#      (-84.31884775236, -74.36540742856),
#      (-84.31935391347, -74.36540742856),
#      (-84.3197961835, -74.3655844723),
#      (-84.3192900167, -74.3655844723)]],
#    [[(-84.36459522217, -74.3606272324),
#      (-84.3651012296, -74.3606272324),
#      (-84.36554387977, -74.36080427723),
#      (-84.36503786665, -74.36080427723),
#      (-84.36459522217, -74.3606272324)]],
#    [[(-84.36105442464, -74.35921087232),
#      (-84.36061186973, -74.35903382713),
#      (-84.36111782596, -74.35903382713),
#      (-84.36156038655, -74.35921087232),
#      (-84.36105442464, -74.35921087232)]],
#    [[(-84.28532897288, -74.35177493946),
#      (-84.28488747787, -74.35159789257),
#      (-82.44235064733, -73.57892784865),
#      (-82.44275177168, -73.57910507653),
#      (-82.44226968134, -73.57910507653),
#      (-82.44186856215, -73.57892784865)]],
#    [[(-82.4605891144, -73.57910507653),
#      (-82.46018779896, -73.57892784865),
#      (-82.46066988414, -73.57892784865),
#      (-82.46107120474, -73.57910507653),
#      (-82.4605891144, -73.57910507653)]],
#    [[(-82.46637419852, -73.57910507653),
#      (-82.46597282111, -73.57892784865),
#      (-82.46645490629, -73.57892784865),
#      (-82.46685628887, -73.57910507653),
#      (-82.46637419852, -73.57910507653)]],
#    [[(-82.48694394601, -73.57839616476),
#      (-82.48742601569, -73.57839616476),
#      (-82.48782761003, -73.57857339276),
#      (-82.48734553518, -73.57857339276),
#      (-82.48694394601, -73.57839616476)]],
#    [[(-82.47384743938, -73.57857339276),
#      (-82.4734459948, -73.57839616476),
#      (-82.47392806449, -73.57839616476),
#      (-82.47432951423, -73.57857339276),
#      (-82.47384743938, -73.57857339276)]],
#    [[(-82.45456444537, -73.57857339276),
#      (-82.45416320737, -73.57839616476),
#      (-82.45464527706, -73.57839616476),
#      (-82.45504652022, -73.57857339276),
#      (-82.45456444537, -73.57857339276)]],
#    [[(-82.45898390423, -73.57839616476),
#      (-82.45946597391, -73.57839616476),
#      (-82.45986726872, -73.57857339276),
#      (-82.45938519387, -73.57857339276),
#      (-82.45898390423, -73.57839616476)]],
#    [[(-82.48300686153, -73.57857339276),
#      (-82.48260531884, -73.57839616476),
#      (-82.48308738852, -73.57839616476),
#      (-82.48348893638, -73.57857339276),
#      (-82.48300686153, -73.57857339276)]],
#    [[(-82.4791516028, -73.57751002409),
#      (-82.4787501272, -73.57733279582),
#      (-82.47923216591, -73.57733279582),
#      (-82.47963364666, -73.57751002409),
#      (-82.4791516028, -73.57751002409)]],
#    ...]},
#  'links': [{'rel': 'self',
#    'href': 's3://ausseabed-pl019-ingested-data/L2/0224_Bioview_SS012000/ga_ausseabed_706f772a-d0d8-424d-ac4c-1d5f656bc71e_stac-metadata.geojson',
#    'type': <MediaType.JSON: 'application/json'>}],
#  'assets': {'bathymetry_data': {'href': 's3://ausseabed-pl019-ingested-data/L2/0224_Bioview_SS012000/ga_ausseabed_706f772a-d0d8-424d-ac4c-1d5f656bc71e_bathymetry.tiledb',
#    'roles': ['data']},
#   'data_footprint': {'href': 's3://ausseabed-pl019-ingested-data/L2/0224_Bioview_SS012000/ga_ausseabed_706f772a-d0d8-424d-ac4c-1d5f656bc71e_coverage.geojson',
#    'roles': ['data']},
#   'sounding_density': {'href': 's3://ausseabed-pl019-ingested-data/L2/0224_Bioview_SS012000/ga_ausseabed_706f772a-d0d8-424d-ac4c-1d5f656bc71e_soundings-cell-density-resolution-12.geojson',
#    'roles': ['data']}},
#  'bbox': [0.0,
#   -38.89102137088019,
#   -1.5,
#   150.4261983572004,
#   4.67519989605205e-310,
#   1491.449951171875],
#  'stac_extensions': ['https://stac-extensions.github.io/projection/v1.0.0/schema.json',
#   'https://stac-extensions.github.io/pointcloud/v1.0.0/schema.json',
#   'https://stac-extensions.github.io/scientific/v1.0.0/schema.json']}
