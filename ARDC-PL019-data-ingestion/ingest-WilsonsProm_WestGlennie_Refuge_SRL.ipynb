# %%
import boto3
import io
import urllib
import s3fs
import json
from pathlib import Path
import attr
import numpy
import tiledb
import tiledb.cloud
from tiledb.cloud.compute import DelayedArrayUDF, Delayed
import pandas
import geopandas
import fiona
from fiona.session import AWSSession
import pystac
from scipy.stats import skew, kurtosis
import uuid

# %%
import pystac
from pystac.extensions.projection import ProjectionExtension
from pystac.extensions.pointcloud import (
    PointcloudExtension,
    SchemaType,
    PhenomenologyType,
    Schema,
    Statistic,
)

# %%
from reap_gsf import reap, data_model
from bathy_datasets import rhealpix, storage, geometry, asb_spreadsheet, stac_metadata

# %%
session = boto3.Session()
creds = session.get_credentials()

# %%
fs = s3fs.S3FileSystem(key=creds.access_key, secret=creds.secret_key, use_listings_cache=False)

# %%
uid = uuid.uuid4()

# %%
survey_url = "s3://ausseabed-pl019-provided-data/DeakinUniversity/WilsonsProm_WestGlennie_Refuge_SRL/"
outdir_uri = "s3://ausseabed-pl019-ingested-data/L2/WilsonsProm_WestGlennie_Refuge_SRL/"
asb_metadata_uri = "s3://ausseabed-pl019-provided-data/DeakinUniversity/WilsonsProm_WestGlennie_Refuge_SRL/metadata/spreadsheet-metadata.json"

# %%
base_prefix = "ga_ausseabed"
array_name = f"{base_prefix}_{uid}_bathymetry"
array_uri = f"{outdir_uri}{array_name}.tiledb"
tiledb_array_uri = f"tiledb://sixy6e/{array_name}"
soundings_cell_density_uri = f"{outdir_uri}{base_prefix}_{uid}_soundings-cell-density-resolution-12.geojson"
coverage_uri = f"{outdir_uri}{base_prefix}_{uid}_coverage.geojson"
stac_md_uri = f"{outdir_uri}{base_prefix}_{uid}_stac-metadata.geojson"

# %%
files = fs.glob(survey_url + "**.gsf")
len(files)
# Out:
# 10

# %%
fs.ls("s3://ausseabed-pl019-ingested-data/L2/")
# Out:
# ['ausseabed-pl019-ingested-data/L2/',
#  'ausseabed-pl019-ingested-data/L2/WilsonsProm_WestGlennie_Refuge_SRL']

# %%
def get_attributes(json_uri):
    """
    Temporary func for pulling the attributes from a sample GSF file.
    To ensure we only use attributes that the GSF contains.
    """
    with fs.open(json_uri) as src:
        md = json.loads(src.read())
    stream_task = Delayed("sixy6e/retrieve_stream", name="retrieve")(md["gsf_uri"], creds.access_key, creds.secret_key)
    dataframe_task = Delayed("sixy6e/decode_gsf", name="decode", image_name="3.7-geo")(stream_task, slice(10))
    df, finfo = dataframe_task.compute()
    required_attributes = list(df.columns)
    return required_attributes


def get_sonar_metadata(json_uri):
    """
    Temporary func for pulling metadata from a sample GSF file.
    """
    with fs.open(json_uri) as src:
        md = json.loads(src.read())
    stream_task = Delayed("sixy6e/retrieve_stream", name="retrieve")(md["gsf_uri"], creds.access_key, creds.secret_key)
    dataframe_task = Delayed("sixy6e/decode_gsf", name="decode", image_name="3.7-geo")(stream_task, slice(10))
    df, finfo = dataframe_task.compute()
    sonar_metadata = finfo[3].record(0).read(stream_task.result()[0])
    history = attr.asdict(finfo[6].record(0).read(stream_task.result()[0]))
    for key, value in history.items():
        sonar_metadata[key] = value
    return sonar_metadata


def reduce_region_codes(results):
    """
    The reduce part of the map-reduce construct for handling the region_code counts.
    Combine all the region_code counts then summarise the results.
    """
    region_codes = [i[0] for i in results]
    timestamps = [i[1] for i in results]
    df = pandas.concat(region_codes)
    cell_count = df.groupby(["region_code"])["count"].agg("sum").to_frame("count").reset_index()
    
    timestamps_df = pandas.DataFrame(
        {
            "start_datetime": [i[0] for i in timestamps],
            "end_datetime": [i[1] for i in timestamps],
        }
    )

    start_end_timestamp = [
        timestamps_df.start_datetime.min().to_pydatetime(),
        timestamps_df.end_datetime.max().to_pydatetime(),
    ]

    return cell_count, start_end_timestamp


def gather_stats(results):
    """
    Gather the results from all the stats tasks and
    combine into a single dict.
    """
    data = {}
    for item in results:
        for key in item:
            data[key] = item[key]
    return data

# %%
required_attributes = get_attributes(files[0].replace(".gsf", ".json"))

# %%
sonar_metadata = get_sonar_metadata(files[0].replace(".gsf", ".json"))

# %%
config = tiledb.Config(
        {"vfs.s3.aws_access_key_id": creds.access_key, "vfs.s3.aws_secret_access_key": creds.secret_key}
    )
ctx = tiledb.Ctx(config=config)

# %%
storage.create_mbes_array(array_uri, required_attributes, ctx)

# %%
size_limit_mb = 500
processing_node_limit = 30
ping_slice_step = 500
slices_per_node = 3

# %%
node_counter = 0
skipped_files = []
tasks = []
tasks_dict = {n: [] for n in range(processing_node_limit)}
for pathname in files:
    metadata_pathname = pathname.replace(".gsf", ".json")
    base_name = Path(pathname).stem
    with fs.open(metadata_pathname) as src:
        gsf_metadata = json.loads(src.read())

    if (gsf_metadata["size"] / 1024 / 1024) > size_limit_mb:
        skipped_files.append(pathname)
        continue

    ping_count = gsf_metadata["file_record_types"]["GSF_SWATH_BATHYMETRY_PING"]["record_count"]
    slices = [slice(start, start+ping_slice_step) for start in numpy.arange(0, ping_count, ping_slice_step)]
    slice_chunks = [slices[i:i+slices_per_node] for i in range(0, len(slices), slices_per_node)]

    for slice_chunk in slice_chunks:
        start_idx = slice_chunk[0].start
        end_idx = slice_chunk[0].stop
        task_name = f"{base_name}-{start_idx}-{end_idx}-{node_counter}"
        task = Delayed("sixy6e/ingest_gsf_slices", name=task_name, image_name="3.7-geo")(gsf_metadata["gsf_uri"], creds.access_key, creds.secret_key, array_uri, slice_chunk)

        if len(tasks_dict[node_counter]):
            task.depends_on(tasks_dict[node_counter][-1])

        tasks.append(task)
        tasks_dict[node_counter].append(task)
        node_counter += 1

        if node_counter == processing_node_limit:
            node_counter = 0

reduce_task = Delayed(reduce_region_codes, "reduce-region_codes-timestamps", local=True)(tasks)

# %%
reduce_task.visualize()
# Out:
# Visualize(value='{"nodes": ["72014d4a-a52b-48f4-af5d-d1d35f42a432", "d8b2f4d6-a531-481f-83ed-5ae275768e18", "c…

# %%
len(tasks)
# Out:
# 66

# %%
cell_count_df, start_end_timestamps = reduce_task.compute()

# %%
resolution12_df = pandas.DataFrame(
    {
        "region_code": cell_count_df.region_code.str[0:13],
        "count": cell_count_df["count"],
    }
).groupby(
    ["region_code"]
)["count"].agg("sum").to_frame("count").reset_index()

# %%
resolution12_df["geometry"] = rhealpix.rhealpix_geo_boundary(resolution12_df.region_code.values)

# %%
gdf = geopandas.GeoDataFrame(resolution12_df, crs="epsg:4326")

# %%
with fiona.Env(session=AWSSession(aws_access_key_id=creds.access_key, aws_secret_access_key=creds.secret_key)):
    gdf.to_file(soundings_cell_density_uri, driver="GeoJSONSeq", coordinate_precision=11)

# %%
dissolved = geopandas.GeoDataFrame(geometry.dissolve(gdf), crs="epsg:4326")
# Out:
# /opt/conda/lib/python3.7/site-packages/geopandas/_vectorized.py:142: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   aout[:] = out
# /opt/conda/lib/python3.7/site-packages/geopandas/_vectorized.py:142: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   aout[:] = out

# %%
with fiona.Env(session=AWSSession(aws_access_key_id=creds.access_key, aws_secret_access_key=creds.secret_key)):
    dissolved.to_file(coverage_uri, driver="GeoJSONSeq", coordinate_precision=11)

# %%
dggs = rhealpix.RhealpixDGGS.from_ellipsoid()

# %%
area_ha = gdf.shape[0] * dggs.cell_width(12) **2 / 10000
sonar_metadata["area_ha"] = area_ha
area_ha
# Out:
# 407.5839020477999

# %%
with fs.open(asb_metadata_uri) as src:
    asb_metadata = json.loads(src.read())

# %%
tiledb.cloud.register_array(
    uri=array_uri,
    namespace="sixy6e", # Optional, you may register it under your username, or one of your organizations
    array_name=array_name,
    description=asb_metadata["survey_general"]["abstract"],  # Optional 
    access_credentials_name="AusSeabedGMRT-PL019"
)

# %%
with tiledb.open(array_uri, ctx=ctx) as ds:
    schema = ds.schema
    domain = ds.domain
    non_empty_domain = ds.nonempty_domain()

# %%
stats_tasks = []

for i in range(domain.ndim):
    attribute = domain.dim(i).name
    name = f"{attribute}_basic_stats"
    
    stats_tasks.append(
        DelayedArrayUDF(tiledb_array_uri, "sixy6e/basic-statistics", attrs=[attribute], name=name, attribute=attribute)(non_empty_domain)
    )

for i in range(schema.nattr):
    attribute = schema.attr(i).name
    name = f"{attribute}_basic_stats"
    
    if attribute in ["timestamp", "region_code"]:
        continue
        
    stats_tasks.append(
        DelayedArrayUDF(tiledb_array_uri, "sixy6e/basic-statistics", attrs=[attribute], name=name, attribute=attribute)(non_empty_domain)
    )

stats_report = Delayed(gather_stats, local=True, name="stats-report")(stats_tasks)

# %%
stats_report.visualize()
# Out:
# Visualize(value='{"nodes": ["b5a3a1ac-b4c6-428e-99c3-3f6377532ed8", "807ed2cb-9bd1-40aa-909f-48fa34181c9f", "c…

# %%
stats_results = stats_report.compute()

# %%
#tiledb.cloud.deregister_array(tiledb_array_uri)

# %%
crs_info = {
    "horizontal_datum": "epsg:4326",
    "vertical_data": "epsg:4326",
}

# %%
with tiledb.open(array_uri, "w", ctx=ctx) as ds:
    ds.meta["crs_info"] = json.dumps(crs_info)
    ds.meta["basic_statistics"] = json.dumps(stats_results, cls=stac_metadata.Encoder)

# %%
dataset_metadata = stac_metadata.prepare(
    uid,
    sonar_metadata,
    stats_results,
    asb_metadata,
    array_uri,
    coverage_uri,
    soundings_cell_density_uri,
    creds.access_key,
    creds.secret_key,
    start_end_timestamps,
    outdir_uri,
    stac_md_uri,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1295/614754223.py in <module>
# ----> 1 dataset_metadata = stac_metadata.prepare(
#       2     uid,
#       3     sonar_metadata,
#       4     stats_results,
#       5     asb_metadata,
#
# NameError: name 'stac_metadata' is not defined

# %%
dataset_metadata
# Out:
# {'type': 'Feature',
#  'stac_version': '1.0.0',
#  'id': '76826530-a376-497a-a053-06053e9855db',
#  'properties': {'sonar:processed_datetime': datetime.datetime(2016, 6, 18, 0, 37, 21, 662000, tzinfo=datetime.timezone.utc),
#   'sonar:platform_type': 'surface_ship',
#   'sonar:full_raw_data': False,
#   'sonar:roll_compensated': True,
#   'sonar:pitch_compensated': True,
#   'sonar:heave_compensated': True,
#   'sonar:tide_compensated': True,
#   'sonar:number_of_receivers': 1,
#   'sonar:number_of_transmitters': 1,
#   'sonar:depth_calculation': 'corrected',
#   'sonar:ray_tracing': True,
#   'sonar:msb_applied_to_attitude': False,
#   'sonar:heave_removed_from_gps_tc': False,
#   'sonar:utc_offset': 'unknown',
#   'sonar:roll_reference': 'unknown',
#   'sonar:draft_to_apply': 0.0,
#   'sonar:pitch_to_apply': 0.0,
#   'sonar:roll_to_apply': 0.0,
#   'sonar:gyro_to_apply': 0.0,
#   'sonar:position_offset_to_apply': [0.0, 0.0, 0.0],
#   'sonar:antenna_offset_to_apply': [0.0, 0.0, 0.0],
#   'sonar:transducer_offset_to_apply': [0.0, 0.0, 0.0],
#   'sonar:transducer_pitch_offset_to_apply': 0.0,
#   'sonar:transducer_roll_offset_to_apply': 0.0,
#   'sonar:transducer_heading_offset_to_apply': 0.0,
#   'sonar:mru_pitch_to_apply': 0.0,
#   'sonar:mru_roll_to_apply': 0.0,
#   'sonar:mru_heading_to_apply': 0.0,
#   'sonar:mru_offset_to_apply': [0.0, 0.0, 0.0],
#   'sonar:center_of_rotation_offset_to_apply': ['unknown',
#    'unknown',
#    'unknown'],
#   'sonar:position_latency_to_apply': 0.0,
#   'sonar:attitude_latency_to_apply': 0.0,
#   'sonar:depth_sensor_latency_to_apply': 0.0,
#   'sonar:depth_sensor_offset_to_apply': [0.0, 0.0, 0.0],
#   'sonar:rx_transducer_offset_to_apply': [0.0, 0.0, 0.0],
#   'sonar:rx_transducer_pitch_offset_to_apply': 0.0,
#   'sonar:rx_transducer_roll_offset_to_apply': 0.0,
#   'sonar:rx_transducer_heading_offset_to_apply': 0.0,
#   'sonar:applied_draft': 0.0,
#   'sonar:applied_pitch_bias': 0.0,
#   'sonar:applied_roll_bias': -0.08,
#   'sonar:applied_gyro_bias': 0.0,
#   'sonar:applied_position_offset': [0.0, 0.0, 0.0],
#   'sonar:applied_antenna_offset': [0.0, 0.0, 0.0],
#   'sonar:applied_transducer_offset': [0.0, 0.0, 0.0],
#   'sonar:applied_transducer_pitch_offset': 'unknown',
#   'sonar:applied_transducer_roll_offset': 'unknown',
#   'sonar:applied_transducer_heading_offset': 'unknown',
#   'sonar:applied_mru_roll': 0.0,
#   'sonar:applied_mru_pitch': 0.0,
#   'sonar:applied_mru_heading': 0.0,
#   'sonar:applied_mru_offset': [0.0, 0.0, 0.0],
#   'sonar:applied_center_of_rotation_offset': [0.0, 0.0, 0.0],
#   'sonar:applied_position_latency': 0.0,
#   'sonar:applied_attitude_latency': 0.0,
#   'sonar:applied_depth_sensor_latency': 0.0,
#   'sonar:applied_depth_sensor_offset': [0.0, 0.0, 0.0],
#   'sonar:applied_rx_transducer_offset': ['unknown', 'unknown', 'unknown'],
#   'sonar:applied_rx_transducer_pitch_offset': 'unknown',
#   'sonar:applied_rx_transducer_roll_offset': 'unknown',
#   'sonar:applied_rx_transducer_heading_offset': 'unknown',
#   'sonar:geoid': 'wgs-84',
#   'sonar:tidal_datum': 'unknown',
#   'sonar:processing_timestamp': datetime.datetime(2021, 10, 26, 9, 0, 34, tzinfo=datetime.timezone.utc),
#   'sonar:machine_name': 'DESKTOP-0BUAHRU',
#   'sonar:operator_name': 'swines',
#   'sonar:command': 'HIPStoGSF',
#   'sonar:comment': 'version 11.3.8',
#   'sonar:area_ha': 407.5839020477999,
#   'sonar:horizontal_datum': 'epsg:4326',
#   'sonar:vertical_data': 'epsg:4326',
#   'processing:lineage': "The Wilsons Promontory West Glennie and Refuge Cove bathymetry survey was acquired by Deakin University Marine Mapping lab onboard the M/V Yolla over 1 day in 2016 (18/06) using a Kongsberg EM2040c. This survey was part of a Parks Victoria project to assess the impact of the Wilsons Promontory MNP on southern rock lobster populations. These data were collected to provide habitat information in the sampling locations outside the park where no multibeam data existed. The data were originally processed in an earlier version of CARIS but have since been upgraded to  CARIS 11.3 and the following processing steps were performed.\n1. Import into CARIS\n2. Post-process POS MV data in POSPAC (PPP Solution)\n3. Apply SBETS to data in CARIS\n4. Georeferenced bathymetry and computed TPU\n5. Generated a CUBE surface  \n6. Manually removed any erroneous soundings \nConverted GSF's to TileDB sparse array",
#   'title': 'Wilsons Prom SRL - West Glennie & Refuge Cove Survey',
#   'description': 'The Wilsons Promontory West Glennie and Refuge Cove bathymetry survey was acquired by Deakin University Marine Mapping lab onboard the M/V Yolla over 1 day in 2016 (18/06) using a Kongsberg EM2040c. This survey was part of a Parks Victoria project to assess the impact of the Wilsons Promontory MNP on southern rock lobster populations. These data were collected to provide habitat information in the sampling locations outside the park where no multibeam data existed.',
#   'start_datetime': '2016-06-18T00:37:21.656000Z',
#   'end_datetime': '2016-06-18T09:30:27.545000Z',
#   'created': '2022-03-15T23:55:45.879042Z',
#   'instruments': ['Kongsberg EM2040c'],
#   'providers': [{'name': 'Deakin University',
#     'roles': [<ProviderRole.PRODUCER: 'producer'>]},
#    {'name': 'Geoscience Australia', 'roles': [<ProviderRole.HOST: 'host'>]}],
#   'proj:epsg': 4326,
#   'pc:count': 36144800,
#   'pc:type': <PhenomenologyType.SONAR: 'sonar'>,
#   'pc:encoding': 'TileDB',
#   'pc:schemas': [{'name': 'X', 'size': 8, 'type': 'floating'},
#    {'name': 'Y', 'size': 8, 'type': 'floating'},
#    {'name': 'Z', 'size': 4, 'type': 'floating'},
#    {'name': 'timestamp', 'size': 8, 'type': 'other'},
#    {'name': 'across_track', 'size': 4, 'type': 'floating'},
#    {'name': 'along_track', 'size': 4, 'type': 'floating'},
#    {'name': 'travel_time', 'size': 4, 'type': 'floating'},
#    {'name': 'beam_angle', 'size': 4, 'type': 'floating'},
#    {'name': 'beam_angle_forward', 'size': 4, 'type': 'floating'},
#    {'name': 'vertical_error', 'size': 4, 'type': 'floating'},
#    {'name': 'horizontal_error', 'size': 4, 'type': 'floating'},
#    {'name': 'sector_number', 'size': 1, 'type': 'unsigned'},
#    {'name': 'beam_flags', 'size': 1, 'type': 'unsigned'},
#    {'name': 'ping_flags', 'size': 1, 'type': 'unsigned'},
#    {'name': 'tide_corrector', 'size': 4, 'type': 'floating'},
#    {'name': 'depth_corrector', 'size': 4, 'type': 'floating'},
#    {'name': 'heading', 'size': 4, 'type': 'floating'},
#    {'name': 'pitch', 'size': 4, 'type': 'floating'},
#    {'name': 'roll', 'size': 4, 'type': 'floating'},
#    {'name': 'heave', 'size': 4, 'type': 'floating'},
#    {'name': 'course', 'size': 4, 'type': 'floating'},
#    {'name': 'speed', 'size': 4, 'type': 'floating'},
#    {'name': 'height', 'size': 4, 'type': 'floating'},
#    {'name': 'separation', 'size': 4, 'type': 'floating'},
#    {'name': 'gps_tide_corrector', 'size': 4, 'type': 'floating'},
#    {'name': 'centre_beam', 'size': 1, 'type': 'unsigned'},
#    {'name': 'beam_number', 'size': 2, 'type': 'unsigned'},
#    {'name': 'region_code', 'size': 0, 'type': 'other'}],
#   'pc:statistics': [{'minimum': 146.21535242297753,
#     'maximum': 146.48656118807733,
#     'count': 36144800,
#     'total': 5289786473.320106,
#     'mean': 146.34986148270582,
#     'stddev': 0.12083067197341892,
#     'skewness': 0.05006373543202747,
#     'kurtosis': -1.9857971423177474,
#     'name': 'X'},
#    {'minimum': -39.12816496520456,
#     'maximum': -39.01868398560331,
#     'count': 36144800,
#     'total': -1412115909.233046,
#     'mean': -39.06830053653765,
#     'stddev': 0.03528090028703668,
#     'skewness': -0.06351483134548362,
#     'kurtosis': -1.5400718196905465,
#     'name': 'Y'},
#    {'minimum': -1.072,
#     'maximum': 463.908,
#     'count': 36144800,
#     'total': 878567100.0,
#     'mean': 24.306873,
#     'stddev': 30.769999,
#     'skewness': 7.972424309491363,
#     'kurtosis': 84.91048475747193,
#     'name': 'Z'},
#    {'minimum': -158.67,
#     'maximum': 180.46,
#     'count': 36144800,
#     'total': 30047164.0,
#     'mean': 0.8312998,
#     'stddev': 33.155037,
#     'skewness': 0.16965084248763276,
#     'kurtosis': 1.7016892800275087,
#     'name': 'across_track'},
#    {'minimum': -15.0335,
#     'maximum': 11.829,
#     'count': 36144800,
#     'total': -695511.75,
#     'mean': -0.019242374,
#     'stddev': 0.810788,
#     'skewness': -0.5749986372377865,
#     'kurtosis': 14.895047583881013,
#     'name': 'along_track'},
#    {'minimum': 0.0,
#     'maximum': 0.26745,
#     'count': 36144800,
#     'total': 1689443.2,
#     'mean': 0.046740975,
#     'stddev': 0.03341336,
#     'skewness': 1.4561033803856491,
#     'kurtosis': 2.0882782497087824,
#     'name': 'travel_time'},
#    {'minimum': -84.20333,
#     'maximum': 88.80334,
#     'count': 36144800,
#     'total': 16636501.0,
#     'mean': 0.4602737,
#     'stddev': 44.872787,
#     'skewness': 0.023576720364134256,
#     'kurtosis': -1.5324525762606962,
#     'name': 'beam_angle'},
#    {'minimum': nan,
#     'maximum': nan,
#     'count': 36144800,
#     'total': nan,
#     'mean': nan,
#     'stddev': nan,
#     'skewness': nan,
#     'kurtosis': nan,
#     'name': 'beam_angle_forward'},
#    {'minimum': 0.019,
#     'maximum': 7.291,
#     'count': 36144800,
#     'total': 6242906.0,
#     'mean': 0.17271934,
#     'stddev': 0.15484922,
#     'skewness': 2.935348177386317,
#     'kurtosis': 21.939034552600603,
#     'name': 'vertical_error'},
#    {'minimum': 0.13875,
#     'maximum': 1.585,
#     'count': 36144800,
#     'total': 37069400.0,
#     'mean': 1.0255804,
#     'stddev': 0.3673278,
#     'skewness': -0.7226190010623482,
#     'kurtosis': -0.6924637251267196,
#     'name': 'horizontal_error'},
#    {'minimum': 0,
#     'maximum': 0,
#     'count': 36144800,
#     'total': 0,
#     'mean': 0.0,
#     'stddev': 0.0,
#     'skewness': 0.0,
#     'kurtosis': -3.0,
#     'name': 'sector_number'},
#    {'minimum': 0,
#     'maximum': 9,
#     'count': 36144800,
#     'total': 52940747,
#     'mean': 1.4646850169318961,
#     'stddev': 3.1483304685256437,
#     'skewness': 1.9053340471392453,
#     'kurtosis': 1.7462466413917541,
#     'name': 'beam_flags'},
#    {'minimum': 0,
#     'maximum': 249,
#     'count': 36144800,
#     'total': 2671200,
#     'mean': 0.07390274672982006,
#     'stddev': 4.212994799316301,
#     'skewness': 57.798995832042564,
#     'kurtosis': 3341.265995989069,
#     'name': 'ping_flags'},
#    {'minimum': -327.56,
#     'maximum': 327.37,
#     'count': 36144800,
#     'total': -57472124.0,
#     'mean': -1.5900524,
#     'stddev': 23.361942,
#     'skewness': 2.201883311184944,
#     'kurtosis': 127.95767795735367,
#     'name': 'tide_corrector'},
#    {'minimum': 99.99,
#     'maximum': 99.99,
#     'count': 36144800,
#     'total': 3614212400.0,
#     'mean': 99.99259,
#     'stddev': 0.0025939092,
#     'skewness': -1.000121241203255,
#     'kurtosis': -1.9998875016586513,
#     'name': 'depth_corrector'},
#    {'minimum': 0.0,
#     'maximum': 360.0,
#     'count': 36144800,
#     'total': 7091360300.0,
#     'mean': 196.1931,
#     'stddev': 104.43975,
#     'skewness': -0.13785003972364185,
#     'kurtosis': -1.081000007367084,
#     'name': 'heading'},
#    {'minimum': -11.79,
#     'maximum': 16.24,
#     'count': 36144800,
#     'total': 45619904.0,
#     'mean': 1.2621429,
#     'stddev': 2.2034779,
#     'skewness': -0.03401344311575913,
#     'kurtosis': 2.894120062462198,
#     'name': 'pitch'},
#    {'minimum': -26.37,
#     'maximum': 21.23,
#     'count': 36144800,
#     'total': -54127176.0,
#     'mean': -1.4975094,
#     'stddev': 3.6804636,
#     'skewness': -0.29482521950751883,
#     'kurtosis': 2.8531943453461857,
#     'name': 'roll'},
#    {'minimum': -2.29,
#     'maximum': 2.0,
#     'count': 36144800,
#     'total': 1560852.8,
#     'mean': 0.043183327,
#     'stddev': 0.37450105,
#     'skewness': -0.05668209551392154,
#     'kurtosis': 2.8944512602211194,
#     'name': 'heave'},
#    {'minimum': 0.0,
#     'maximum': 360.0,
#     'count': 36144800,
#     'total': 7002649600.0,
#     'mean': 193.73878,
#     'stddev': 104.37203,
#     'skewness': -0.10314584942431038,
#     'kurtosis': -1.1003532116842512,
#     'name': 'course'},
#    {'minimum': 0.81,
#     'maximum': 99.0,
#     'count': 36144800,
#     'total': 199463360.0,
#      (146.47140510424, -39.03443763698),
#      (146.47157445511, -39.03443763698),
#      (146.47157445511, -39.03462254342),
#      (146.47157445511, -39.03480745034),
#      (146.47157445511, -39.03499235774),
#      (146.47140510424, -39.03499235774),
#      (146.47140510424, -39.03517726561),
#      (146.47140510424, -39.03536217396),
#      (146.47140510424, -39.03554708278),
#      (146.47123575336, -39.03554708278),
#      (146.47123575336, -39.03573199208),
#      (146.47123575336, -39.03591690186),
#      (146.47123575336, -39.03610181211),
#      (146.47106640248, -39.03610181211),
#      (146.47106640248, -39.03628672284),
#      (146.47106640248, -39.03647163404),
#      (146.47106640248, -39.03665654572),
#      (146.47106640248, -39.03684145788),
#      (146.47106640248, -39.03702637051),
#      (146.47123575336, -39.03702637051),
#      (146.47123575336, -39.03721128362),
#      (146.47123575336, -39.0373961972),
#      (146.47140510424, -39.0373961972),
#      (146.47140510424, -39.03758111126),
#      (146.47157445511, -39.03758111126),
#      (146.47157445511, -39.0377660258),
#      (146.47157445511, -39.03795094081),
#      (146.47174380599, -39.03795094081),
#      (146.47191315687, -39.03795094081),
#      (146.47191315687, -39.0381358563),
#      (146.47208250775, -39.0381358563),
#      (146.47208250775, -39.03832077227),
#      (146.47225185863, -39.03832077227),
#      (146.47225185863, -39.03850568871),
#      (146.4724212095, -39.03850568871),
#      (146.4724212095, -39.03869060563),
#      (146.47259056038, -39.03869060563),
#      (146.47259056038, -39.03887552302),
#      (146.47275991126, -39.03887552302),
#      (146.47275991126, -39.03906044089),
#      (146.47292926214, -39.03906044089),
#      (146.47309861302, -39.03906044089),
#      (146.47309861302, -39.03924535923),
#      (146.47326796389, -39.03924535923),
#      (146.47343731477, -39.03924535923),
#      (146.47343731477, -39.03943027805),
#      (146.47360666565, -39.03943027805),
#      (146.47360666565, -39.03961519735),
#      (146.47377601653, -39.03961519735),
#      (146.47377601653, -39.03980011713),
#      (146.47394536741, -39.03980011713),
#      (146.47394536741, -39.03998503738),
#      (146.47394536741, -39.0401699581),
#      (146.47411471828, -39.0401699581),
#      ...]]]},
#  'links': [{'rel': 'self',
#    'href': 's3://ausseabed-pl019-ingested-data/L2/WilsonsProm_WestGlennie_Refuge_SRL/ga_ausseabed_76826530-a376-497a-a053-06053e9855db_stac-metadata.geojson',
#    'type': <MediaType.JSON: 'application/json'>}],
#  'assets': {'bathymetry_data': {'href': 's3://ausseabed-pl019-ingested-data/L2/WilsonsProm_WestGlennie_Refuge_SRL/ga_ausseabed_76826530-a376-497a-a053-06053e9855db_bathymetry.tiledb',
#    'roles': ['data']},
#   'data_footprint': {'href': 's3://ausseabed-pl019-ingested-data/L2/WilsonsProm_WestGlennie_Refuge_SRL/ga_ausseabed_76826530-a376-497a-a053-06053e9855db_coverage.geojson',
#    'roles': ['data']},
#   'sounding_density': {'href': 's3://ausseabed-pl019-ingested-data/L2/WilsonsProm_WestGlennie_Refuge_SRL/ga_ausseabed_76826530-a376-497a-a053-06053e9855db_soundings-cell-density-resolution-12.geojson',
#    'roles': ['data']}},
#  'bbox': [146.21535242297753,
#   -39.12816496520456,
#   -1.072,
#   146.48656118807733,
#   -39.01868398560331,
#   463.908],
#  'stac_extensions': ['https://stac-extensions.github.io/projection/v1.0.0/schema.json',
#   'https://stac-extensions.github.io/pointcloud/v1.0.0/schema.json',
#   'https://stac-extensions.github.io/scientific/v1.0.0/schema.json']}
